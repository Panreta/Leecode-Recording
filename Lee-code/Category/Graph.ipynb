# %% [markdown]
# # 200.Number of Islands

# %%
def numIslands(self, grid):
        """
        :type grid: List[List[str]]
        :rtype: int
        """
        m,n = len(grid),len(grid[0])
        count = 0

        def dfs(i,j): # Bug1: No return, even put return in the end, the graph like [1,1]
            # it will jump between grid[0] and grid[1] and never stop
            if grid[i][j] == "1":
                grid[i][j] = '0'

            if i - 1 > 0:
                dfs(i - 1,j)
            if i + 1 < m:
                dfs(i + 1,j)
            if j - 1 > 0:
                dfs(i, j - 1)
            if j + 1 < 0:
                dfs(i, j + 1)

        for i in range(m):
            for j in range(n):
                if grid[i][j] == "1":
                    dfs(i,j)
                    count += 1
        return count

# %% [markdown]
# Still wrong cuz elif only runs one branch.

# %%
def dfs(i,j):
            if grid[i][j] == "1":
                grid[i][j] = '0'

            elif i - 1 > 0:
                dfs(i - 1,j)
            elif i + 1 < m:
                dfs(i + 1,j)
            elif j - 1 > 0:
                dfs(i, j - 1)
            elif j + 1 < 0:
                dfs(i, j + 1)
            else:
                return

# %% [markdown]
# So put the return at the start to avoid recurring.

# %%
def numIslands(self, grid):
        """
        :type grid: List[List[str]]
        :rtype: int
        """
        m,n = len(grid),len(grid[0])
        count = 0

        def dfs(i,j):
            if i < 0 or i >= m or j < 0 or j >= n or grid[i][j] == '0':
                return
            grid[i][j] = '0'
            dfs(i - 1,j)
            dfs(i + 1,j)
            dfs(i, j - 1)
            dfs(i, j + 1)

        for i in range(m):
            for j in range(n):
                if grid[i][j] == "1":
                    dfs(i,j)
                    count += 1
        return count

# %% [markdown]
# 130. Surrounded Regions

# %%
def solve(self, board):
        """
        :type board: List[List[str]]
        :rtype: None Do not return anything, modify board in-place instead.
        """
        m,n = len(board),len(board[0])
        
        def dfs(i,j):
            if i < 0 or i >=m or j < 0 or j >= n or board[i][j] != 'O':
                return
            board[i][j] = 'X'
            dfs(i - 1,j)
            dfs(i + 1,j)
            dfs(i,j - 1)
            dfs(i,j + 1)

        def dfs1(i,j):
            if i < 0 or i >=m or j < 0 or j >= n or board[i][j] != 'O':
                return
            board[i][j] = 'P'
            dfs1(i - 1,j)
            dfs1(i + 1,j)
            dfs1(i,j - 1)
            dfs1(i,j + 1)

        # Boundary
        for i in range(m):
            dfs1(i,0)
            dfs1(i,n - 1)
        for j in range(n):
            dfs1(0,j)
            dfs1(m - 1,j)

        for i in range(m):
            for j in range(n):
                if board[i][j] == 'O':
                    dfs(i,j)

        for i in range(m):
            for j in range(n):
                if board[i][j] == 'P':
                    board[i][j] = 'O'
        return board

# %% [markdown]
# Easier way:

# %%
def solve(self, board):
    m, n = len(board), len(board[0])

    def dfs(i, j, mark):
        if i < 0 or i >= m or j < 0 or j >= n or board[i][j] != 'O':
            return
        board[i][j] = mark
        dfs(i-1, j, mark)
        dfs(i+1, j, mark)
        dfs(i, j-1, mark)
        dfs(i, j+1, mark)

    # mark border-connected O's as 'P'
    for i in range(m):
        dfs(i, 0,   'P')
        dfs(i, n-1, 'P')
    for j in range(n):
        dfs(0,   j, 'P')
        dfs(m-1, j, 'P')

    # flip remaining O's to X, restore P's to O
    for i in range(m):
        for j in range(n):
            if board[i][j] == 'O': board[i][j] = 'X'
            if board[i][j] == 'P': board[i][j] = 'O'

# %% [markdown]
# 133. Clone Graph

# %%
def cloneGraph(self, node):
        """
        :type node: Node
        :rtype: Node
        """
        if not node:
            return None

        mapping = {}

        def dfs(node):
            if node in mapping:
                return mapping[node]

            clone = Node(node.val)
            mapping[node] = clone

            for neighbor in node.neighbors:
                clone.neighbors.append(dfs(neighbor))
            return clone
        return dfs(node)

# %% [markdown]
# 399. Evaluate Division

# %%
from collections import defaultdict,deque
def calcEquation(equations, values, queries):
    """
    :type equations: List[List[str]]
    :type values: List[float]
    :type queries: List[List[str]]
    :rtype: List[float]
    """
    graph = defaultdict(dict)
    for (a,b), k in zip(equations,values):
        graph[a][b] = k
        graph[b][a] = 1.0/k

    def bfs(src,dst):
        if src not in graph or dst not in graph:
            return -1.0

        if src == dst:
            return 1.0

        visited = {src}
        q = deque([(src,1.0)])

        while q:
            node,prod = q.popleft()
            if node == dst:
                return prod
            for neighbor, weight in graph[node].items():
                if neighbor not in visited:
                    visited.add(neighbor)
                    q.append((neighbor,prod*weight))
        return -1.0

    return [bfs(c,d) for c,d in queries]

# %%
from collections import defaultdict
graph = defaultdict(dict)
equations = [["a","b"],["b","c"]]
values = [2.0,3.0]
for (a,b), k in zip(equations,values):
    graph[a][b] = k
    graph[b][a] = 1.0/k
print(graph)
# Out:
# defaultdict(<class 'dict'>, {'a': {'b': 2.0}, 'b': {'a': 0.5, 'c': 3.0}, 'c': {'b': 0.3333333333333333}})

# %% [markdown]
# 207. Course Schedule

# %%
from collections import deque,defaultdict
def canFinish(self, numCourses, prerequisites):
    """
    :type numCourses: int
    :type prerequisites: List[List[int]]
    :rtype: bool
    """
    graph = defaultdict(list)
    indegree = [0] * numCourses

    for end,start in prerequisites:
        graph[start].append(end)
        indegree[end] += 1

    q = deque([i for i in range(numCourses) if indegree[i] == 0])
    completed = 0

    while q:
        course = q.popleft()
        completed += 1
        for neighbor in graph[course]:
            indegree[neighbor] -= 1
            if indegree[neighbor] == 0:
                q.append(neighbor)

    return completed == numCourses
